# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb
# %matplotlib inline

# %%
coffee_fao = pd.read_csv("DataSets/WorldFoodProductionFao/coffee-fao-data.csv")
coffee_fao
# Out:
#      Domain Code                        Domain  Area Code (M49)      Area  \
# 0            QCL  Crops and livestock products               24    Angola
# 1            QCL  Crops and livestock products               24    Angola
# 2            QCL  Crops and livestock products               24    Angola
# 3            QCL  Crops and livestock products               24    Angola
# 4            QCL  Crops and livestock products               24    Angola
# ...          ...                           ...              ...       ...
# 5208         QCL  Crops and livestock products              716  Zimbabwe
# 5209         QCL  Crops and livestock products              716  Zimbabwe
# 5210         QCL  Crops and livestock products              716  Zimbabwe
# 5211         QCL  Crops and livestock products              716  Zimbabwe
# 5212         QCL  Crops and livestock products              716  Zimbabwe
#
#       Element Code     Element  Item Code (CPC)           Item  Year Code  \
# ...

# %%
coffee_fao.drop(['Domain Code',
                 'Domain',
                 'Area Code (M49)',
                 'Element Code',
                 'Element', 
                 'Year Code',
                 'Unit', 
                 'Flag',
                 'Flag Description',
                 'Note',
                 'Item Code (CPC)'
                ], axis=1, inplace=True)

# %%
coffee_fao.rename(columns={
    'Area': 'country',
    'Value': 'value',
    'Item': 'commodity',
    'Year': 'year'
}, inplace=True)

# %%
coffee_fao.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5213 entries, 0 to 5212
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   country    5213 non-null   object
#  1   commodity  5213 non-null   object
#  2   year       5213 non-null   int64
#  3   value      5213 non-null   float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 163.0+ KB

# %%
coffee_fao['country'].unique()
# Out:
# array(['Angola', 'Belize', 'Benin', 'Bolivia (Plurinational State of)',
#        'Brazil', 'Burundi', 'Cabo Verde', 'Cambodia', 'Cameroon',
#        'Central African Republic', 'China', 'China, mainland',
#        'China, Taiwan Province of', 'Colombia', 'Comoros', 'Congo',
#        'Cook Islands', 'Costa Rica', "Côte d'Ivoire", 'Cuba',
#        'Democratic Republic of the Congo', 'Dominica',
#        'Dominican Republic', 'Ecuador', 'El Salvador',
#        'Equatorial Guinea', 'Ethiopia', 'Ethiopia PDR', 'Fiji',
#        'French Polynesia', 'Gabon', 'Ghana', 'Guadeloupe', 'Guatemala',
#        'Guinea', 'Guyana', 'Haiti', 'Honduras', 'India', 'Indonesia',
#        'Jamaica', 'Kenya', "Lao People's Democratic Republic", 'Liberia',
#        'Madagascar', 'Malawi', 'Malaysia', 'Martinique', 'Mauritius',
#        'Mexico', 'Mozambique', 'Myanmar', 'Nepal', 'New Caledonia',
#        'Nicaragua', 'Nigeria', 'Panama', 'Papua New Guinea', 'Paraguay',
# ...

# %%
coffee_fao['country'] = coffee_fao['country'].replace({
    'Bolivia (Plurinational State of)': 'Bolivia',
    'China, mainland': 'China',
    'China, Taiwan Province of': 'Taiwan',
    "Côte d'Ivoire": "Cote d'Ivoire",
    'Ethiopia PDR': 'Ethiopia',
    'Venezuela (Bolivarian Republic of)': 'Venezuela',
    'United Republic of Tanzania': 'Tanzania',
    'Viet Nam': 'Vietnam'
})

# %%
coffee_fao['commodity'] = coffee_fao['commodity'].replace({'Coffee, green': 'coffee'})

# %%
coffee_fao
# Out:
#        country commodity  year      value
# 0       Angola    coffee  1961  168600.00
# 1       Angola    coffee  1962  185000.00
# 2       Angola    coffee  1963  168300.00
# 3       Angola    coffee  1964  198200.00
# 4       Angola    coffee  1965  205000.00
# ...        ...       ...   ...        ...
# 5208  Zimbabwe    coffee  2018     627.78
# 5209  Zimbabwe    coffee  2019     670.37
# 5210  Zimbabwe    coffee  2020     660.49
# 5211  Zimbabwe    coffee  2021     652.88
# 5212  Zimbabwe    coffee  2022     661.25
#
# [5213 rows x 4 columns]

# %%
cocoa_fao = pd.read_csv("DataSets/WorldFoodProductionFao/cocoa-fao-data.csv")
cocoa_fao
# Out:
#      Domain Code                        Domain  Area Code (M49)  \
# 0            QCL  Crops and livestock products               24
# 1            QCL  Crops and livestock products               24
# 2            QCL  Crops and livestock products               24
# 3            QCL  Crops and livestock products               24
# 4            QCL  Crops and livestock products               24
# ...          ...                           ...              ...
# 3723         QCL  Crops and livestock products              862
# 3724         QCL  Crops and livestock products              704
# 3725         QCL  Crops and livestock products              704
# 3726         QCL  Crops and livestock products              704
# 3727         QCL  Crops and livestock products              704
#
#                                     Area  Element Code     Element  \
# 0                                 Angola          5510  Production
# ...

# %%
cocoa_fao.drop(['Domain Code',
                 'Domain',
                 'Area Code (M49)',
                 'Element Code',
                 'Element', 
                 'Year Code',
                 'Unit', 
                 'Flag',
                 'Flag Description',
                 'Note',
                 'Item Code (CPC)'
                ], axis=1, inplace=True)

# %%
cocoa_fao.rename(columns={
    'Area': 'country',
    'Value': 'value',
    'Item': 'commodity',
    'Year': 'year'
}, inplace=True)

# %%
cocoa_fao.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3728 entries, 0 to 3727
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   country    3728 non-null   object
#  1   commodity  3728 non-null   object
#  2   year       3728 non-null   int64
#  3   value      3728 non-null   float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 116.6+ KB

# %%
cocoa_fao['country'].unique()
# Out:
# array(['Angola', 'Belize', 'Benin', 'Bolivia (Plurinational State of)',
#        'Brazil', 'Cameroon', 'Central African Republic',
#        'China, Taiwan Province of', 'Colombia', 'Comoros', 'Congo',
#        'Costa Rica', "Côte d'Ivoire", 'Cuba',
#        'Democratic Republic of the Congo', 'Dominica',
#        'Dominican Republic', 'Ecuador', 'El Salvador',
#        'Equatorial Guinea', 'Fiji', 'Gabon', 'Ghana', 'Grenada',
#        'Guadeloupe', 'Guatemala', 'Guinea', 'Guyana', 'Haiti', 'Honduras',
#        'India', 'Indonesia', 'Jamaica', 'Liberia', 'Madagascar',
#        'Malaysia', 'Martinique', 'Mexico',
#        'Micronesia (Federated States of)', 'Nicaragua', 'Nigeria',
#        'Panama', 'Papua New Guinea', 'Peru', 'Philippines', 'Saint Lucia',
#        'Saint Vincent and the Grenadines', 'Samoa',
#        'Sao Tome and Principe', 'Sierra Leone', 'Solomon Islands',
#        'Sri Lanka', 'Suriname', 'Thailand', 'Timor-Leste', 'Togo',
# ...

# %%
cocoa_fao['country'] = cocoa_fao['country'].replace({
    'Bolivia (Plurinational State of)': 'Bolivia',
    'China, Taiwan Province of': 'Taiwan',
    'Micronesia (Federated States of)': 'Micronesia',
    "Côte d'Ivoire": "Cote d'Ivoire",
    'United Republic of Tanzania': 'Tanzania',
    'Venezuela (Bolivarian Republic of)': 'Venezuela',
    'Viet Nam': 'Vietnam'
})

# %%
cocoa_fao['commodity'] = cocoa_fao['commodity'].replace({'Cocoa beans': 'cocoa'})

# %%
cocoa_fao
# Out:
#         country commodity  year    value
# 0        Angola     cocoa  1961    400.0
# 1        Angola     cocoa  1962    400.0
# 2        Angola     cocoa  1963    300.0
# 3        Angola     cocoa  1964    300.0
# 4        Angola     cocoa  1965    400.0
# ...         ...       ...   ...      ...
# 3723  Venezuela     cocoa  2022  29325.0
# 3724    VietNam     cocoa  2019   3000.0
# 3725    VietNam     cocoa  2020   2000.0
# 3726    VietNam     cocoa  2021   2000.0
# 3727    VietNam     cocoa  2022   1500.0
#
# [3728 rows x 4 columns]

# %%
orange_fao = pd.read_csv("DataSets/WorldFoodProductionFao/orange-fao-data.csv")
orange_fao
# Out:
#      Domain Code                        Domain  Area Code (M49)         Area  \
# 0            QCL  Crops and livestock products                4  Afghanistan
# 1            QCL  Crops and livestock products                4  Afghanistan
# 2            QCL  Crops and livestock products                4  Afghanistan
# 3            QCL  Crops and livestock products                4  Afghanistan
# 4            QCL  Crops and livestock products                4  Afghanistan
# ...          ...                           ...              ...          ...
# 7397         QCL  Crops and livestock products              716     Zimbabwe
# 7398         QCL  Crops and livestock products              716     Zimbabwe
# 7399         QCL  Crops and livestock products              716     Zimbabwe
# 7400         QCL  Crops and livestock products              716     Zimbabwe
# 7401         QCL  Crops and livestock products              716     Zimbabwe
#
# ...

# %%
orange_fao.drop(['Domain Code',
                 'Domain',
                 'Area Code (M49)',
                 'Element Code',
                 'Element', 
                 'Year Code',
                 'Unit', 
                 'Flag',
                 'Flag Description',
                 'Note',
                 'Item Code (CPC)'
                ], axis=1, inplace=True)

# %%
orange_fao.rename(columns={
    'Area': 'country',
    'Value': 'value',
    'Item': 'commodity',
    'Year': 'year'
}, inplace=True)

# %%
orange_fao.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7402 entries, 0 to 7401
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   country    7402 non-null   object
#  1   commodity  7402 non-null   object
#  2   year       7402 non-null   int64
#  3   value      7402 non-null   float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 231.4+ KB

# %%
orange_fao['country'].unique()
# Out:
# array(['Afghanistan', 'Albania', 'Algeria', 'Argentina', 'Australia',
#        'Austria', 'Azerbaijan', 'Bahamas', 'Bangladesh', 'Belgium',
#        'Belize', 'Benin', 'Bhutan', 'Bolivia (Plurinational State of)',
#        'Bosnia and Herzegovina', 'Botswana', 'Brazil',
#        'Brunei Darussalam', 'Bulgaria', 'Burkina Faso', 'Cambodia',
#        'Central African Republic', 'Chile', 'China', 'China, mainland',
#        'China, Taiwan Province of', 'Colombia', 'Congo', 'Cook Islands',
#        'Costa Rica', "Côte d'Ivoire", 'Croatia', 'Cuba', 'Cyprus',
#        'Czechia', 'Democratic Republic of the Congo', 'Denmark',
#        'Djibouti', 'Dominica', 'Dominican Republic', 'Ecuador', 'Egypt',
#        'El Salvador', 'Estonia', 'Eswatini', 'Ethiopia', 'Ethiopia PDR',
#        'Fiji', 'Finland', 'France', 'French Guiana', 'French Polynesia',
#        'Georgia', 'Germany', 'Ghana', 'Greece', 'Grenada', 'Guadeloupe',
#        'Guatemala', 'Guinea', 'Guinea-Bissau', 'Guyana', 'Haiti',
# ...

# %%
orange_fao['country'] = orange_fao['country'].replace({
    'Bolivia (Plurinational State of)': 'Bolivia',
    'China, Taiwan Province of': 'Taiwan',
    'China, mainland': 'China',
    'Micronesia (Federated States of)': 'Micronesia',
    "Côte d'Ivoire": "Cote d'Ivoire",
    'United Republic of Tanzania': 'Tanzania',
    'Venezuela (Bolivarian Republic of)': 'Venezuela',
    'Ethiopia PDR': 'Ethiopia',
    'Netherlands (Kingdom of the)': 'Netherlands',
    'Iran (Islamic Republic of)': 'Iran',
    'Sudan (former)': 'Sudan',
    'Yugoslav SFR': 'Yugoslavia',
    'Viet Nam': 'Vietnam'
})

# %%
orange_fao['commodity'] = orange_fao['commodity'].replace({'Oranges': 'orange'})

# %%
orange_fao
# Out:
#           country commodity  year      value
# 0     Afghanistan    orange  1961   10100.00
# 1     Afghanistan    orange  1962   10100.00
# 2     Afghanistan    orange  1963   10100.00
# 3     Afghanistan    orange  1964   12400.00
# 4     Afghanistan    orange  1965   13700.00
# ...           ...       ...   ...        ...
# 7397     Zimbabwe    orange  2018   97891.77
# 7398     Zimbabwe    orange  2019  100651.40
# 7399     Zimbabwe    orange  2020  100864.67
# 7400     Zimbabwe    orange  2021   99802.61
# 7401     Zimbabwe    orange  2022  100439.56
#
# [7402 rows x 4 columns]

# %%
food_fao = pd.concat([cocoa_fao, coffee_fao], axis=0)

# %%
food_fao = pd.concat([food_fao, orange_fao], axis=0)

# %%
food_fao
# Out:
#        country commodity  year      value
# 0       Angola     cocoa  1961     400.00
# 1       Angola     cocoa  1962     400.00
# 2       Angola     cocoa  1963     300.00
# 3       Angola     cocoa  1964     300.00
# 4       Angola     cocoa  1965     400.00
# ...        ...       ...   ...        ...
# 7397  Zimbabwe    orange  2018   97891.77
# 7398  Zimbabwe    orange  2019  100651.40
# 7399  Zimbabwe    orange  2020  100864.67
# 7400  Zimbabwe    orange  2021   99802.61
# 7401  Zimbabwe    orange  2022  100439.56
#
# [16343 rows x 4 columns]

# %%
food = (food[~food['country'].str.contains('FAO')])

# %%
non_country = ['Europe', 'European Union (27)', 'Low-income countries', 
               'Lower-middle-income countries', 'Oceania', 'Upper-middle-income countries', 
               'World', 'High-income countries', 'Africa', 'South America']
for i in non_country:
    food = food[~food['country'].apply(lambda x: i in x)]

# %%
food['country'] = food['country'].replace({
    'Ethiopia (former)': 'Ethiopia',
    'Micronesia (country)': 'Micronesia',
    'Sudan (former)': 'Sudan',
})

# %%
food['country'].unique()
# Out:
# array(['Afghanistan', 'Albania', 'Algeria', 'Angola',
#        'Antigua and Barbuda', 'Argentina', 'Armenia', 'Asia', 'Australia',
#        'Austria', 'Azerbaijan', 'Bahamas', 'Bangladesh', 'Barbados',
#        'Belarus', 'Belgium', 'Belize', 'Benin', 'Bhutan', 'Bolivia',
#        'Bosnia and Herzegovina', 'Botswana', 'Brazil', 'Bulgaria',
#        'Burkina Faso', 'Burundi', 'Cambodia', 'Cameroon', 'Canada',
#        'Cape Verde', 'Chad', 'Chile', 'China', 'Colombia', 'Comoros',
#        'Congo', 'Costa Rica', "Cote d'Ivoire", 'Croatia', 'Cuba',
#        'Czechia', 'Czechoslovakia', 'Democratic Republic of Congo',
#        'Denmark', 'Djibouti', 'Dominica', 'Dominican Republic',
#        'East Timor', 'Ecuador', 'Egypt', 'El Salvador', 'Eritrea',
#        'Estonia', 'Eswatini', 'Ethiopia', 'Fiji', 'Finland', 'France',
#        'French Guiana', 'Gabon', 'Gambia', 'Georgia', 'Germany', 'Ghana',
#        'Greece', 'Grenada', 'Guadeloupe', 'Guatemala', 'Guinea',
# ...

# %%
food
# Out:
#            country  Year       orange       coffee        cocoa
# 0      Afghanistan  1961    10100.000   870970.000   835368.000
# 1      Afghanistan  1962    10100.000   883512.000   867170.000
# 2      Afghanistan  1963    10100.000   996674.000   922621.000
# 3      Afghanistan  1964    12400.000  1162048.000  1190061.000
# 4      Afghanistan  1965    13700.000  1075084.000   874245.000
# ...            ...   ...          ...          ...          ...
# 11907     Zimbabwe  2017   129055.800       63.200    34945.000
# 11908     Zimbabwe  2018   168074.000       68.000    34659.800
# 11909     Zimbabwe  2019  1134136.812    30401.400    20961.132
# 11910     Zimbabwe  2020    72179.400   574723.374   158022.122
# 11911     Zimbabwe  2021  3597076.600   590070.590     2696.200
#
# [9331 rows x 5 columns]

# %%
food.rename(columns={'Year': 'year'}, inplace=True)

# %%
# food['year'] = pd.to_datetime(food['year'], format='%Y')

# %%
food
# Out:
#            country  year       orange       coffee        cocoa
# 0      Afghanistan  1961    10100.000   870970.000   835368.000
# 1      Afghanistan  1962    10100.000   883512.000   867170.000
# 2      Afghanistan  1963    10100.000   996674.000   922621.000
# 3      Afghanistan  1964    12400.000  1162048.000  1190061.000
# 4      Afghanistan  1965    13700.000  1075084.000   874245.000
# ...            ...   ...          ...          ...          ...
# 11907     Zimbabwe  2017   129055.800       63.200    34945.000
# 11908     Zimbabwe  2018   168074.000       68.000    34659.800
# 11909     Zimbabwe  2019  1134136.812    30401.400    20961.132
# 11910     Zimbabwe  2020    72179.400   574723.374   158022.122
# 11911     Zimbabwe  2021  3597076.600   590070.590     2696.200
#
# [9331 rows x 5 columns]

# %%
melted_food = food.melt(id_vars=['country', 'year'], value_vars=['cocoa', 'coffee', 'orange'], var_name='commodity', value_name='value')

# %%
melted_food
# Out:
#            country  year commodity        value
# 0      Afghanistan  1961     cocoa   835368.000
# 1      Afghanistan  1962     cocoa   867170.000
# 2      Afghanistan  1963     cocoa   922621.000
# 3      Afghanistan  1964     cocoa  1190061.000
# 4      Afghanistan  1965     cocoa   874245.000
# ...            ...   ...       ...          ...
# 27988     Zimbabwe  2017    orange   129055.800
# 27989     Zimbabwe  2018    orange   168074.000
# 27990     Zimbabwe  2019    orange  1134136.812
# 27991     Zimbabwe  2020    orange    72179.400
# 27992     Zimbabwe  2021    orange  3597076.600
#
# [27993 rows x 4 columns]

# %%
group_cocoa = food.groupby('country')['orange'].sum()

# %%
group_cocoa.nlargest(5)
# Out:
# country
# Sao Tome and Principe    2.852348e+09
# Puerto Rico              1.218423e+09
# New Caledonia            9.428764e+08
# New Zealand              7.512573e+08
# Argentina                7.083512e+08
# Name: orange, dtype: float64

# %%
countries = food['country']

# %%
co_land_temp = pd.read_csv("DataSets/GlobalLandTemperatures/GlobalLandTemperaturesByCountry.csv")
co_land_temp
# Out:
#                 dt  AverageTemperature  AverageTemperatureUncertainty  \
# 0       1743-11-01               4.384                          2.294
# 1       1743-12-01                 NaN                            NaN
# 2       1744-01-01                 NaN                            NaN
# 3       1744-02-01                 NaN                            NaN
# 4       1744-03-01                 NaN                            NaN
# ...            ...                 ...                            ...
# 577457  2013-05-01              19.059                          1.022
# 577458  2013-06-01              17.613                          0.473
# 577459  2013-07-01              17.000                          0.453
# 577460  2013-08-01              19.759                          0.717
# 577461  2013-09-01                 NaN                            NaN
#
#          Country
# 0          Åland
# 1          Åland
# 2          Åland
# 3          Åland
# 4          Åland
# ...

# %%
co_land_temp.drop(['AverageTemperatureUncertainty'], axis=1, inplace=True)

# %%
co_land_temp.rename(columns={
    'Country': 'country',
    'AverageTemperature': 'av_temperature',
    'dt': 'date'
}, inplace=True)

# %%
co_land_temp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 577462 entries, 0 to 577461
# Data columns (total 3 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   date            577462 non-null  object
#  1   av_temperature  544811 non-null  float64
#  2   country         577462 non-null  object
# dtypes: float64(1), object(2)
# memory usage: 13.2+ MB

# %%
co_land_temp.dropna(inplace=True)

# %%
non_matching = ['Curaçao', 'Saint Barthélemy', 'Åland']
for i in non_matching:
    co_land_temp = co_land_temp[~co_land_temp['country'].apply(lambda x: i in x)]

# %%
co_land_temp['country'] = co_land_temp['country'].replace("Côte D'Ivoire", "Cote d'Ivoire")

# %%
co_land_temp['country'].unique()
# Out:
# array(['Afghanistan', 'Africa', 'Albania', 'Algeria', 'American Samoa',
#        'Andorra', 'Angola', 'Anguilla', 'Antigua And Barbuda',
#        'Argentina', 'Armenia', 'Aruba', 'Asia', 'Australia', 'Austria',
#        'Azerbaijan', 'Bahamas', 'Bahrain', 'Baker Island', 'Bangladesh',
#        'Barbados', 'Belarus', 'Belgium', 'Belize', 'Benin', 'Bhutan',
#        'Bolivia', 'Bonaire, Saint Eustatius And Saba',
#        'Bosnia And Herzegovina', 'Botswana', 'Brazil',
#        'British Virgin Islands', 'Bulgaria', 'Burkina Faso', 'Burma',
#        'Burundi', "Cote d'Ivoire", 'Cambodia', 'Cameroon', 'Canada',
#        'Cape Verde', 'Cayman Islands', 'Central African Republic', 'Chad',
#        'Chile', 'China', 'Christmas Island', 'Colombia', 'Comoros',
#        'Congo (Democratic Republic Of The)', 'Congo', 'Costa Rica',
#        'Croatia', 'Cuba', 'Cyprus', 'Czech Republic', 'Denmark (Europe)',
#        'Denmark', 'Djibouti', 'Dominica', 'Dominican Republic', 'Ecuador',
# ...

# %%
co_land_temp
# Out:
#               date  av_temperature      country
# 3239    1838-04-01          13.008  Afghanistan
# 3241    1838-06-01          23.950  Afghanistan
# 3242    1838-07-01          26.877  Afghanistan
# 3243    1838-08-01          24.938  Afghanistan
# 3244    1838-09-01          18.981  Afghanistan
# ...            ...             ...          ...
# 577456  2013-04-01          21.142     Zimbabwe
# 577457  2013-05-01          19.059     Zimbabwe
# 577458  2013-06-01          17.613     Zimbabwe
# 577459  2013-07-01          17.000     Zimbabwe
# 577460  2013-08-01          19.759     Zimbabwe
#
# [537473 rows x 3 columns]

# %%
co_land_temp[co_land_temp['date'] >= '2013-08-01']
# Out:
#               date  av_temperature         country
# 5343    2013-08-01          26.031     Afghanistan
# 7308    2013-08-01          25.911          Africa
# 10547   2013-08-01          24.793         Albania
# 13268   2013-08-01          33.234         Algeria
# 15029   2013-08-01          27.000  American Samoa
# ...            ...             ...             ...
# 569157  2013-09-01          28.991  Virgin Islands
# 571877  2013-08-01          28.564  Western Sahara
# 573530  2013-08-01          30.833           Yemen
# 575495  2013-08-01          20.887          Zambia
# 577460  2013-08-01          19.759        Zimbabwe
#
# [260 rows x 3 columns]

# %%
co_land_temp[co_land_temp['date'] == '2013-09-01']
# Out:
#               date  av_temperature                    country
# 45516   2013-09-01          28.657                    Bahamas
# 63463   2013-09-01          27.969                     Belize
# 81567   2013-09-01          28.991     British Virgin Islands
# 100195  2013-09-01           7.922                     Canada
# 104461  2013-09-01          29.753             Cayman Islands
# 125540  2013-09-01          26.871                 Costa Rica
# 131068  2013-09-01          28.424                       Cuba
# 151132  2013-09-01          28.046         Dominican Republic
# 157469  2013-09-01          26.405                El Salvador
# 220331  2013-09-01          25.655                  Guatemala
# 232078  2013-09-01          28.577                      Haiti
# 235131  2013-09-01          26.789                   Honduras
# 267483  2013-09-01          28.398                    Jamaica
# 340582  2013-09-01          24.990                     Mexico
# ...

# %%
co_land_temp.drop(co_land_temp[co_land_temp['date'] == '2013-09-01'].index, inplace=True)

# %%
co_land_temp
# Out:
#               date  av_temperature      country
# 3239    1838-04-01          13.008  Afghanistan
# 3241    1838-06-01          23.950  Afghanistan
# 3242    1838-07-01          26.877  Afghanistan
# 3243    1838-08-01          24.938  Afghanistan
# 3244    1838-09-01          18.981  Afghanistan
# ...            ...             ...          ...
# 577456  2013-04-01          21.142     Zimbabwe
# 577457  2013-05-01          19.059     Zimbabwe
# 577458  2013-06-01          17.613     Zimbabwe
# 577459  2013-07-01          17.000     Zimbabwe
# 577460  2013-08-01          19.759     Zimbabwe
#
# [537452 rows x 3 columns]

# %%
state_land_temp = pd.read_csv("DataSets/GlobalLandTemperatures/GlobalLandTemperaturesByState.csv")

# %%
state_land_temp.drop(['AverageTemperatureUncertainty'], axis=1, inplace=True)

# %%
state_land_temp.dropna(inplace=True)

# %%
state_land_temp.rename(columns={
    'Country': 'country',
    'AverageTemperature': 'av_temperature',
    'State': 'state',
    'dt': 'date'
}, inplace=True)

# %%
state_land_temp['country'].unique()
# Out:
# array(['Brazil', 'Russia', 'United States', 'Canada', 'India', 'China',
#        'Australia'], dtype=object)

# %%
state_land_temp['state'].unique()
# Out:
# array(['Acre', 'Adygey', 'Aga Buryat', 'Alabama', 'Alagoas', 'Alaska',
#        'Alberta', 'Altay', 'Amazonas', 'Amur', 'Andaman And Nicobar',
#        'Andhra Pradesh', 'Anhui', 'Arizona', 'Arkansas', "Arkhangel'Sk",
#        'Arunachal Pradesh', 'Assam', "Astrakhan'",
#        'Australian Capital Territory', 'Bahia', 'Bashkortostan',
#        'Beijing', 'Belgorod', 'Bihar', 'British Columbia', 'Bryansk',
#        'Buryat', 'California', 'Chandigarh', 'Chechnya', 'Chelyabinsk',
#        'Chhattisgarh', 'Chita', 'Chongqing', 'Chukot', 'Chuvash',
#        'City Of St. Petersburg', 'Colorado', 'Connecticut',
#        'Dadra And Nagar Haveli', 'Dagestan', 'Daman And Diu', 'Delaware',
#        'Delhi', 'District Of Columbia', 'Distrito Federal', 'Evenk',
#        'Florida', 'Fujian', 'Gansu', 'Georgia (State)', 'Goa',
#        'Gorno Altay', 'Guangdong', 'Guangxi', 'Guizhou', 'Gujarat',
#        'Hainan', 'Haryana', 'Hawaii', 'Hebei', 'Heilongjiang', 'Henan',
# ...

# %%
cocoa = pd.read_csv("DataSets/Commodities/Cocoa_data.csv")
cocoa
# Out:
#             date    open     high     low   close  volume
# 0     2000-01-03   840.0    846.0   820.0   830.0    2426
# 1     2000-01-04   830.0    841.0   823.0   836.0    1957
# 2     2000-01-05   840.0    850.0   828.0   831.0    3975
# 3     2000-01-06   830.0    847.0   824.0   841.0    3454
# 4     2000-01-07   848.0    855.0   836.0   853.0    5008
# ...          ...     ...      ...     ...     ...     ...
# 6072  2024-03-21  8395.0   8653.0  8149.0  8559.0   21272
# 6073  2024-03-22  8573.0   8960.0  8465.0  8939.0   16403
# 6074  2024-03-25  8921.0   9684.0  8889.0  9649.0   19698
# 6075  2024-03-26  9847.0  10080.0  9574.0  9622.0   26263
# 6076  2024-03-27  9509.0   9917.0  9267.0  9897.0       0
#
# [6077 rows x 6 columns]

# %%
cocoa['commodity'] = 'cocoa'

# %%
coffee = pd.read_csv("DataSets/Commodities/Coffee_data.csv")
coffee
# Out:
#             date        open        high         low       close  volume
# 0     2000-01-03  124.000000  124.000000  116.099998  116.500000    6640
# 1     2000-01-04  116.500000  120.500000  115.750000  116.250000    5492
# 2     2000-01-05  115.000000  121.000000  115.000000  118.599998    6165
# 3     2000-01-06  119.000000  121.400002  116.500000  116.849998    5094
# 4     2000-01-07  117.750000  117.750000  113.800003  114.150002    6855
# ...          ...         ...         ...         ...         ...     ...
# 6069  2024-03-21  183.850006  188.399994  183.050003  185.699997   23116
# 6070  2024-03-22  186.000000  188.199997  184.550003  184.850006   21361
# 6071  2024-03-25  185.149994  186.250000  183.350006  185.649994   18995
# 6072  2024-03-26  185.649994  189.449997  185.300003  188.050003   21863
# 6073  2024-03-27  188.050003  192.500000  187.149994  191.050003       0
#
# [6074 rows x 6 columns]

# %%
coffee['commodity'] = 'coffee'

# %%
orange_juice = pd.read_csv("DataSets/Commodities/Orange_Juice_data.csv")
orange_juice
# Out:
#            date        open        high         low       close  volume
# 0    2021-09-07  147.000000  147.000000  147.000000  147.000000       0
# 1    2021-09-08  145.550003  145.550003  144.000000  143.100006       4
# 2    2021-09-09  144.250000  144.250000  144.250000  144.250000       0
# 3    2021-09-10  147.100006  147.100006  147.100006  147.100006     462
# 4    2021-09-13  141.649994  142.699997  140.899994  142.100006     349
# ..          ...         ...         ...         ...         ...     ...
# 639  2024-03-21  346.500000  367.850006  346.500000  358.399994     997
# 640  2024-03-22  358.549988  368.399994  357.350006  367.700012     537
# 641  2024-03-25  368.200012  376.000000  366.350006  370.950012     782
# 642  2024-03-26  373.100006  377.000000  371.450012  373.100006     416
# 643  2024-03-27  374.000000  375.899994  363.200012  370.799988       0
#
# [644 rows x 6 columns]

# %%
orange_juice['commodity'] = 'orange'

# %%
commodities = pd.concat([cocoa, coffee], axis=0)

# %%
commodities = pd.concat([commodities, orange_juice], axis=0)

# %%
commodities
# Out:
#            date        open        high         low       close  volume  \
# 0    2000-01-03  840.000000  846.000000  820.000000  830.000000    2426
# 1    2000-01-04  830.000000  841.000000  823.000000  836.000000    1957
# 2    2000-01-05  840.000000  850.000000  828.000000  831.000000    3975
# 3    2000-01-06  830.000000  847.000000  824.000000  841.000000    3454
# 4    2000-01-07  848.000000  855.000000  836.000000  853.000000    5008
# ..          ...         ...         ...         ...         ...     ...
# 639  2024-03-21  346.500000  367.850006  346.500000  358.399994     997
# 640  2024-03-22  358.549988  368.399994  357.350006  367.700012     537
# 641  2024-03-25  368.200012  376.000000  366.350006  370.950012     782
# 642  2024-03-26  373.100006  377.000000  371.450012  373.100006     416
# 643  2024-03-27  374.000000  375.899994  363.200012  370.799988       0
#
#     commodity
# 0       cocoa
# 1       cocoa
# 2       cocoa
# 3       cocoa
# 4       cocoa
# ...

# %%
commodities.reset_index(drop=True)
# Out:
#              date        open        high         low       close  volume  \
# 0      2000-01-03  840.000000  846.000000  820.000000  830.000000    2426
# 1      2000-01-04  830.000000  841.000000  823.000000  836.000000    1957
# 2      2000-01-05  840.000000  850.000000  828.000000  831.000000    3975
# 3      2000-01-06  830.000000  847.000000  824.000000  841.000000    3454
# 4      2000-01-07  848.000000  855.000000  836.000000  853.000000    5008
# ...           ...         ...         ...         ...         ...     ...
# 12790  2024-03-21  346.500000  367.850006  346.500000  358.399994     997
# 12791  2024-03-22  358.549988  368.399994  357.350006  367.700012     537
# 12792  2024-03-25  368.200012  376.000000  366.350006  370.950012     782
# 12793  2024-03-26  373.100006  377.000000  371.450012  373.100006     416
# 12794  2024-03-27  374.000000  375.899994  363.200012  370.799988       0
#
#       commodity
# 0         cocoa
# 1         cocoa
# 2         cocoa
# ...

# %%
countries.duplicated().sum()

# %%
countries.drop_duplicates(keep='first', inplace=True, ignore_index=True)

# %%
countries

# %%
commodity = ['cocoa', 'coffee', 'orange']

# %%
commodity = pd.DataFrame(commodity, columns=['commodity'])

# %%
commodity.to_csv('commodity.csv', encoding='utf-8', index=False, header=True)

# %%
# countries.to_csv('countries.csv', encoding='utf-8', index=True, header=True)

# %%
# commodities.to_csv('commodities.csv', encoding='utf-8', index=False)

# %%
# food_fao.to_csv('agriculture_production.csv', encoding='utf-8', index=False)

# %%
co_land_temp.to_csv('country_land_temperature.csv', encoding='utf-8', index=False)

# %%
# state_land_temp.to_csv('state_land_temperature.csv', encoding='utf-8', index=False)
